# %%
import pandas as pd
import numpy as np
import json

json_file_path="./1000.json" 

with open(json_file_path,'rt', encoding='UTF8') as j:
    contents=json.loads(j.read())

# %%
a = contents['I0760']['row'][1]['LCLAS_NM']
a
# Out:
# '건강기능식품'

# %%
LCLAS_NM=[]
SCLAS_CD=[]
HELT_ITM_GRP_NM=[]
MLSFC_NM=[]
SCLAS_NM=[]
HELT_ITM_GRP_CD=[]
LCLAS_CD=[]
MLSFC_CD=[]

for i in range(len(contents['I0760']['row'])):
    LCLAS_NM.append(contents['I0760']['row'][i]['LCLAS_NM'])
    SCLAS_CD.append(contents['I0760']['row'][i]['SCLAS_CD'])
    HELT_ITM_GRP_NM.append(contents['I0760']['row'][i]['HELT_ITM_GRP_NM'])
    MLSFC_NM.append(contents['I0760']['row'][i]['MLSFC_NM'])
    SCLAS_NM.append(contents['I0760']['row'][i]['SCLAS_NM'])
    HELT_ITM_GRP_CD.append(contents['I0760']['row'][i]['HELT_ITM_GRP_CD'])
    LCLAS_CD.append(contents['I0760']['row'][i]['LCLAS_CD'])
    MLSFC_CD.append(contents['I0760']['row'][i]['MLSFC_CD'])

    
Health=pd.DataFrame({"LCLAS_NM":LCLAS_NM,
                    "SCLAS_CD":SCLAS_CD,
                    "HELT_ITM_GRP_NM":HELT_ITM_GRP_NM,
                    "MLSFC_NM":MLSFC_NM,
                    "SCLAS_NM":SCLAS_NM,
                    "HELT_ITM_GRP_CD":HELT_ITM_GRP_CD,
                    "LCLAS_CD":LCLAS_CD,
                    "MLSFC_CD":MLSFC_CD})
Health
# Out:
#     LCLAS_NM   SCLAS_CD       HELT_ITM_GRP_NM      MLSFC_NM      SCLAS_NM  \
# 0     건강기능식품  599000000           프랑스해안송껍질추출물  개별인정형 건강기능식품  개별인정형 건강기능식품
# 1     건강기능식품  599000000              이소말토올리고당  개별인정형 건강기능식품  개별인정형 건강기능식품
# 2     건강기능식품  599000000             황금추출물등복합물  개별인정형 건강기능식품  개별인정형 건강기능식품
# 3     건강기능식품  599000000             사탕수수왁스알코올  개별인정형 건강기능식품  개별인정형 건강기능식품
# 4     건강기능식품  599000000  Dimethylsulfone(MSM)  개별인정형 건강기능식품  개별인정형 건강기능식품
# ..       ...        ...                   ...           ...           ...
# 580   건강기능식품  599000000             회화나무열매추출물  개별인정형 건강기능식품  개별인정형 건강기능식품
# 581   건강기능식품  599000000                  타가토스  개별인정형 건강기능식품  개별인정형 건강기능식품
# 582   건강기능식품  599000000      밀전분유래 난소화성말토덱스트린  개별인정형 건강기능식품  개별인정형 건강기능식품
# 583   건강기능식품  599000000  Dimethylsulfone(MSM)  개별인정형 건강기능식품  개별인정형 건강기능식품
# 584   건강기능식품  599000000              폴리감마글루탐산  개별인정형 건강기능식품  개별인정형 건강기능식품
#
#     HELT_ITM_GRP_CD   LCLAS_CD   MLSFC_CD
# ...
